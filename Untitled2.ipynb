# %% [markdown]
# <a href="https://colab.research.google.com/github/NajmulAlam25/Gamer-responsive-website/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome programme ")
# Out:
# welcome programme
